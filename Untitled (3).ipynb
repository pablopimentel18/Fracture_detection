# %%
from ultralytics import YOLO

# %%
model = YOLO('best.pt')

# %%
model.val()
# Out:
# Ultralytics 8.4.20 🚀 Python-3.11.10 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 80GB HBM3, 81089MiB)
# YOLOv12x summary (fused): 283 layers, 59,044,499 parameters, 0 gradients, 198.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1472.3±336.0 MB/s, size: 802.9 KB)
# val: Scanning /home/jovyan/privado/classificacao/pablo_pimentel/fracture/GRAZPEDWRI/GRAZPEDWRI_YOLO_dataset/val/labels.cache... 4066 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4066/4066 348.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 255/255 10.9it/s 23.5s0.1ss
#                    all       4066       9405      0.194     0.0918     0.0664     0.0258
# Speed: 0.6ms preprocess, 2.7ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/jovyan/privado/classificacao/pablo_pimentel/fracture/GRAZPEDWRI/GRAZPEDWRI_YOLO_dataset/runs/detect/val18
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ...

# %%
model.val()
# Out:
# Ultralytics 8.3.218 🚀 Python-3.11.10 torch-2.5.1+cu124 CPU (Intel Xeon Platinum 8480C)
# YOLOv12x summary (fused): 283 layers, 59,044,499 parameters, 0 gradients, 198.5 GFLOPs
# val: Fast image access ✅ (ping: 0.2±0.0 ms, read: 1301.5±100.1 MB/s, size: 720.3 KB)
# val: Scanning /home/jovyan/compartilhado/classificacao/pablo_pimentel/fracture/GRAZPEDWRI/GRAZPEDWRI_YOLO_dataset/val/labels.cache... 4066 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4066/4066 4.9Mit/s 0.0s0s
# /root/anaconda3/envs/lapixdl/lib/python3.11/site-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 255/255 0.1it/s 30:05<4.5s
#                    all       4066       9405      0.945      0.885      0.951       0.65
# Speed: 0.7ms preprocess, 429.0ms inference, 0.0ms loss, 0.2ms postprocess per image
# ...

# %%
results = model.train(
    data="data.yaml", epochs=300, imgsz=640, mode='train', task='detect', device=4)
# Out:
# New https://pypi.org/project/ultralytics/8.3.225 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.218 🚀 Python-3.11.10 torch-2.5.1+cu124 CUDA:4 (NVIDIA H100 80GB HBM3, 81090MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")

model.val()
# Out:
# Ultralytics 8.3.218 🚀 Python-3.11.10 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 80GB HBM3, 81090MiB)
# YOLOv12l summary (fused): 283 layers, 26,346,011 parameters, 0 gradients, 88.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3704.4±585.3 MB/s, size: 578.1 KB)
# val: Scanning /home/jovyan/compartilhado/classificacao/pablo_pimentel/fracture/GRAZPEDWRI/GRAZPEDWRI_YOLO_dataset/val/labels.cache... 4066 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4066/4066 5.5Mit/s 0.0s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 255/255 5.1it/s 50.0s<0.2s
#                    all       4066       9405      0.685      0.587      0.611      0.408
#            boneanomaly         37         47      0.328       0.17      0.188     0.0758
#             bonelesion          5          5        0.4        0.4       0.21      0.121
#            foreignbody          3          3          1          0      0.345      0.311
# ...
