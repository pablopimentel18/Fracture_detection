# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo12l.pt')

# %%
results = model.train(
    data='data.yaml',
    epochs=100,
    imgsz=640,
    mode='train',
    task='detect'
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.21 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.20 🚀 Python-3.11.10 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 80GB HBM3, 81089MiB)
# ...

# %%
model.val()
# Out:
# Ultralytics 8.4.20 🚀 Python-3.11.10 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 80GB HBM3, 81089MiB)
# YOLOv12l summary (fused): 283 layers, 26,344,469 parameters, 0 gradients, 88.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 202.3±53.0 MB/s, size: 8.9 KB)
# val: Scanning /home/jovyan/privado/classificacao/pablo_pimentel/fracture/new_data/valid/labels.cache... 348 images, 175 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 348/348 91.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 6.4it/s 3.4s<0.1s
#                    all        348        204       0.39       0.32      0.287      0.107
#         elbow positive         28         29      0.189      0.172     0.0738     0.0183
#       fingers positive         41         48      0.476      0.292      0.205     0.0767
#       forearm fracture         37         43      0.465      0.419      0.439      0.185
# ...
