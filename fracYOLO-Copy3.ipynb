# %%
from ultralytics import YOLO

# %%
model = YOLO("best.pt")

# %%
results = model.train(
    data="data.yaml",   
    mode='train',
    task='detect',
    epochs=500,     
    batch=8,             
    imgsz=1280,       
    save=True,
    device=[1,2,5,6],
    pretrained=True,
    patience=150,           
    plots=True, 
    exist_ok=True,
    lr0=0.001,
    single_cls=True,
    freeze=15,
    degrees=0.9,
)
# Out:
# Ultralytics 8.3.231 🚀 Python-3.11.10 torch-2.5.1+cu124 CUDA:1 (NVIDIA H100 80GB HBM3, 81090MiB)
#                                                        CUDA:2 (NVIDIA H100 80GB HBM3, 81090MiB)
#                                                        CUDA:5 (NVIDIA H100 80GB HBM3, 81090MiB)
#                                                        CUDA:6 (NVIDIA H100 80GB HBM3, 81090MiB)
# ...

# %%
model = YOLO("./runs/detect/train7_top_ate_o_momento/weights/best.pt")

# %%
model.val(batch=16, imgsz=640, device='cpu')
# Out:
# Ultralytics 8.3.218 🚀 Python-3.11.10 torch-2.5.1+cu124 CPU (Intel Xeon Platinum 8480C)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1027.4±316.8 MB/s, size: 17.3 KB)
# val: Scanning /home/jovyan/compartilhado/classificacao/pablo_pimentel/fracture/FracAtlas/FracAtlas_YOLO/valid/labels.cache... 82 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 82/82 328.5Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.1it/s 51.3s11.6s
#                    all         82         91      0.797      0.484      0.527      0.237
# Speed: 1.0ms preprocess, 621.8ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/jovyan/compartilhado/classificacao/pablo_pimentel/fracture/FracAtlas/FracAtlas_YOLO/runs/detect/val23
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# ...
