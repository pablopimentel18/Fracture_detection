# %%
from ultralytics import YOLO

# %%
model = YOLO('best.pt')

# %%
results = model.train(data="data.yaml", epochs=750, imgsz=980, single_cls=True, mode='train', task='detect', device=[1,2,3,4], close_mosaic=50)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.11.10 torch-2.5.1+cu124 CUDA:1 (NVIDIA H100 80GB HBM3, 81089MiB)
#                                                       CUDA:2 (NVIDIA H100 80GB HBM3, 81089MiB)
#                                                       CUDA:3 (NVIDIA H100 80GB HBM3, 81089MiB)
#                                                       CUDA:4 (NVIDIA H100 80GB HBM3, 81089MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO('runs/detect/train12/weights/best.pt')

metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.231 🚀 Python-3.11.10 torch-2.5.1+cu124 CUDA:0 (NVIDIA H100 80GB HBM3, 81090MiB)
# YOLOv12x summary (fused): 283 layers, 59,044,499 parameters, 0 gradients, 198.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1299.2±243.4 MB/s, size: 18.7 KB)
# val: Scanning /home/jovyan/compartilhado/classificacao/pablo_pimentel/fracture/FracAtlas/FracAtlas_YOLO/valid/labels.cache... 82 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 82/82 216.2Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.7it/s 0.9s0.4s
#                    all         82         91      0.705      0.526      0.553      0.262
# Speed: 1.9ms preprocess, 5.6ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/jovyan/compartilhado/classificacao/pablo_pimentel/fracture/FracAtlas/FracAtlas_YOLO/runs/detect/val25
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ...
